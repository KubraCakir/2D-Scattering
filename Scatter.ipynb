# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from ROOT import TCanvas, TGraphErrors, TF1, TH1F, gStyle
from ROOT import gROOT
from array import array
# Out:
# Welcome to JupyROOT 6.16/00

# %%
a=[20]*24
b=[40]*11
c=[60]*33
d=[80]*25
e=[100]*46
f=[120]*60
g=[140]*65
h=[160]*84
i=[180]*77
j=[200]*83
k=[220]*69
l=[240]*45
m=[260]*38
n=[280]*40
o=[300]*37
p=[320]*19
r=[340]*7

# %%
a.extend(b)
a.extend(c)
a.extend(d)
a.extend(e)
a.extend(f)
a.extend(g)
a.extend(h)
a.extend(i)
a.extend(j)
a.extend(k)
a.extend(l)
a.extend(m)
a.extend(n)
a.extend(o)
a.extend(p)
a.extend(r)

# %%
print(a)
# Out:
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140, 
# ...

# %%
c1 = TCanvas( 'c1', 'Scatter', 200, 10, 600, 400 ) 


histo = TH1F("", "Number of scattered particles", 17, 10, 350) 

histo.GetYaxis().SetTitle("dN")
histo.GetXaxis().SetTitle ("#theta#circ")
histo.SetFillColorAlpha(46, 0.5)


for data_point in a:
    histo.Fill(data_point)

histo.Draw()
histo.Draw("E1SAME")
c1.Draw()
c1.SaveAs("histo1.eps")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: eps file histo1.eps has been created

# %%
a1=[20]*31
b1=[40]*30
c1=[60]*70
d1=[80]*65
e1=[100]*84
f1=[120]*105
g1=[140]*134
h1=[160]*167
i1=[180]*144

# %%
a1.extend(b1)
a1.extend(c1)
a1.extend(d1)
a1.extend(e1)
a1.extend(f1)
a1.extend(g1)
a1.extend(h1)
a1.extend(i1)

# %%
print(a1)
# Out:
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100
# ...

# %%
c2 = TCanvas( 'c2', 'Scatter', 200, 10, 600, 400 ) 


histo = TH1F("", "Number of scattered particles", 9, 10, 190) 

histo.GetYaxis().SetTitle("dNmod")
histo.GetXaxis ().SetTitle ("#theta#circ")
histo.SetFillColorAlpha(46, 0.5)



for data_point in a1:
    histo.Fill(data_point)

histo.Draw()
histo.Draw("E1SAME")
c2.Draw()
c2.SaveAs("histo2.eps")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2
# Info in <TCanvas::Print>: eps file histo2.eps has been created

# %%
ndata = 9
y =  array( 'f', [31, 30, 70, 65, 84, 105, 134, 167, 144])
sy1 = np.sqrt(y)
sy = array( 'f', sy1)
z = [10, 20, 30, 40, 50, 60, 70, 80, 90]
x1 = np.sin(np.radians(z))
x =  array( 'f', x1)
sx =  array( 'f', [ 0, 0, 0, 0, 0, 0, 0, 0, 0])
print(x1)
# Out:
# [0.17364818 0.34202014 0.5        0.64278761 0.76604444 0.8660254
#  0.93969262 0.98480775 1.        ]

# %%
c1 = TCanvas( 'c1', 'Counts per Intervalvs sin(#theta/2)', 200, 10, 600, 400 )
             
mygraph = TGraphErrors(ndata,x,y,sx,sy)
mygraph.Draw("A*")
mygraph.SetTitle("Counts per interval vs sin(#theta/2)")
mygraph.GetYaxis().SetTitle("dNmod")
mygraph.GetXaxis().SetTitle ("sin(#theta/2)")
c1.Draw()
c1.SaveAs("plot1.eps")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# Info in <TCanvas::Print>: eps file plot1.eps has been created

# %%
fnew = TF1("fnew","[0]*x+[1]",0,6)
fnew.SetParameters(3.1416, 2.7182)
mygraph.Fit(fnew)
gStyle.SetOptFit(1011)
fnew.Draw("same")
c1.Draw()
c1.SaveAs("plot2.eps")
# Out:
#  FCN=28.8341 FROM MIGRAD    STATUS=CONVERGED      31 CALLS          32 TOTAL
#                      EDM=1.09673e-21    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  p0           1.36828e+02   9.43547e+00   1.21391e-02  -2.92667e-12
#    2  p1          -5.46964e+00   5.59897e+00   7.20329e-03   3.69905e-12
# Info in <TCanvas::Print>: eps file plot2.eps has been created
